# %%
import pandas as pd 
import pipeline as ppl
import numpy as np
import datetime
import yfinance as yf 
import matplotlib.pyplot as plt

# %% [markdown]
# ### hour K

# %%
# import yfinance as yf
# import pandas as pd
# import datetime

# # 設定要抓取的股票代碼
# us_stock = "SMCI"  # Super Micro Computer, Inc.
# tw_stock = "2465.TW"  # 台股麗台科技

# # 設定時間範圍（最近一個月）
# end_date = datetime.datetime.now().date()
# start_date = end_date - datetime.timedelta(days= 360)  # 時間區間較短，適合抓取小時K

# # 抓取資料，設置 interval 為 1 小時
# us_stock_data = yf.download(us_stock, start=start_date, end=end_date, interval='1h')
# tw_stock_data = yf.download(tw_stock, start=start_date, end=end_date, interval='1h')

# # 將美股的時間戳轉換為台灣時間 (UTC+8)
# us_stock_data.index = us_stock_data.index + pd.Timedelta(hours=12)

# # 調整時間溢出
# # 由於台灣市場會比美國市場早結束，因此我們需要手動調整美股數據的日期，使其與台灣市場的日期對齊
# print(us_stock_data.index)
# us_stock_data.index = us_stock_data.index.normalize()  # 去掉時間格式
# print(us_stock_data.index)

# # 對兩者的日期進行對齊（交集）
# common_dates = tw_stock_data.index.intersection(us_stock_data.index)
# tw_common = tw_stock_data.loc[common_dates]
# us_common = us_stock_data.loc[common_dates]

# # 打印結果
# print(f"共有交易日數量: {len(common_dates)}")
# print("--------")
# print("台股（2465.TW）的部分時間：")
# print(tw_common.head())
# print("--------")
# print("美股（SMCI）的部分時間：")
# print(us_common.head())

# %% [markdown]
# ### 日 K  Finmind

# %%
import requests

def get_stock_data(stock_id, start_date, end_date, token):
    url = "https://api.finmindtrade.com/api/v4/data"
    payload = {
        "dataset": "TaiwanStockPrice",  # Dataset for stock prices
        "data_id": stock_id,  # Stock ID for 麗臺 is 2465
        "start_date": start_date,  # Start date for the data
        "end_date": end_date,  # End date for the data
        "token": token
    }

    try:
        # Send GET request to the API
        response = requests.get(url, params=payload)
        response.raise_for_status()  # Check if the request was successful

        # Extract data from the response
        data = response.json()

        # Display the stock data (or process it as needed)
        if "data" in data:
            print(f"Successfully retrieved stock data for stock {stock_id}.")
            # Here you can process the data as needed (e.g., save to CSV, analyze)
            return data["data"]
        else:
            print("No data found.")
            return None

    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"An error occurred: {err}")
        return None

# Example usage
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRlIjoiMjAyNC0wOS0wOSAxNzoyNDozMyIsInVzZXJfaWQiOiIxMDkxMDIwNDkiLCJpcCI6IjM2LjIzMC4zNS4xNDEifQ.PMwWMWdaFZgmVTVyGCAKiKr5rwNZkO0PddorRvAY-PA'

stock_id = "2465"  # Stock ID for 麗臺
start_date = "2023-09-09"  # Replace with your desired start date
end_date = "2024-09-09"  # Replace with your desired end date

# Get stock data for 麗臺 (2465)
stock_data = get_stock_data(stock_id, start_date, end_date, token)

if stock_data:
    for record in stock_data:
        print(record)
        

stock_data = pd.DataFrame
# Out:
# Successfully retrieved stock data for stock 2465.
# {'date': '2023-09-11', 'stock_id': '2465', 'Trading_Volume': 261020, 'Trading_money': 9245063, 'open': 35.65, 'max': 35.85, 'min': 35.2, 'close': 35.3, 'spread': -0.5, 'Trading_turnover': 432}
# {'date': '2023-09-12', 'stock_id': '2465', 'Trading_Volume': 210168, 'Trading_money': 7407347, 'open': 35.3, 'max': 35.35, 'min': 35.1, 'close': 35.15, 'spread': -0.15, 'Trading_turnover': 185}
# {'date': '2023-09-13', 'stock_id': '2465', 'Trading_Volume': 63973, 'Trading_money': 2261912, 'open': 35.95, 'max': 35.95, 'min': 35.15, 'close': 35.35, 'spread': 0.2, 'Trading_turnover': 80}
# {'date': '2023-09-14', 'stock_id': '2465', 'Trading_Volume': 91733, 'Trading_money': 3277862, 'open': 35.55, 'max': 35.8, 'min': 35.55, 'close': 35.75, 'spread': 0.4, 'Trading_turnover': 128}
# {'date': '2023-09-15', 'stock_id': '2465', 'Trading_Volume': 331225, 'Trading_money': 12007318, 'open': 36.2, 'max': 36.5, 'min': 36.0, 'close': 36.15, 'spread': 0.4, 'Trading_turnover': 257}
# {'date': '2023-09-18', 'stock_id': '2465', 'Trading_Volume': 1213190, 'Trading_money': 45542108, 'open': 37.0, 'max': 38.1, 'min': 36.2, 'close': 37.8, 'spread': 1.65, 'Trading_turnover': 1137}
# {'date': '2023-09-19', 'stock_id': '2465', 'Trading_Volume': 755082, 'Trading_money': 28475404, 'open': 37.8, 'max': 38.2, 'min': 37.05, 'close': 38.05, 'spread': 0.25, 'Trading_turnover': 725}
# {'date': '2023-09-20', 'stock_id': '2465', 'Trading_Volume': 468361, 'Trading_money': 17738828, 'open': 38.15, 'max': 38.55, 'min': 37.1, 'close': 37.15, 'spread': -0.9, 'Trading_turnover': 729}
# {'date': '2023-09-21', 'stock_id': '2465', 'Trading_Volume': 187378, 'Trading_money': 6876116, 'open': 37.0, 'max': 37.0, 'min': 36.5, 'close': 36.75, 'spread': -0.4, 'Trading_turnover': 467}
# {'date': '2023-09-22', 'stock_id': '2465', 'Trading_Volume': 110810, 'Trading_money': 4038190, 'open': 36.3, 'max': 36.75, 'min': 36.0, 'close': 36.75, 'spread': 0.0, 'Trading_turnover': 129}
# {'date': '2023-09-25', 'stock_id': '2465', 'Trading_Volume': 128511, 'Trading_money': 4753058, 'open': 36.8, 'max': 37.15, 'min': 36.8, 'close': 36.9, 'spread': 0.15, 'Trading_turnover': 160}
# {'date': '2023-09-26', 'stock_id': '2465', 'Trading_Volume': 173427, 'Trading_money': 6434427, 'open': 37.1, 'max': 37.2, 'min': 37.0, 'close': 37.0, 'spread': 0.1, 'Trading_turnover': 131}
# {'date': '2023-09-27', 'stock_id': '2465', 'Trading_Volume': 74278, 'Trading_money': 2731102, 'open': 37.0, 'max': 37.0, 'min': 36.6, 'close': 36.9, 'spread': -0.1, 'Trading_turnover': 86}
# {'date': '2023-09-28', 'stock_id': '2465', 'Trading_Volume': 98053, 'Trading_money': 3622306, 'open': 37.25, 'max': 37.25, 'min': 36.85, 'close': 36.9, 'spread': 0.0, 'Trading_turnover': 82}
# {'date': '2023-10-02', 'stock_id': '2465', 'Trading_Volume': 423581, 'Trading_money': 16039391, 'open': 37.0, 'max': 38.3, 'min': 37.0, 'close': 38.25, 'spread': 1.35, 'Trading_turnover': 334}
# {'date': '2023-10-03', 'stock_id': '2465', 'Trading_Volume': 188224, 'Trading_money': 7139885, 'open': 37.8, 'max': 38.1, 'min': 37.6, 'close': 37.8, 'spread': -0.45, 'Trading_turnover': 182}
# {'date': '2023-10-04', 'stock_id': '2465', 'Trading_Volume': 1249678, 'Trading_money': 48626767, 'open': 37.95, 'max': 39.85, 'min': 37.25, 'close': 39.4, 'spread': 1.6, 'Trading_turnover': 1081}
# {'date': '2023-10-05', 'stock_id': '2465', 'Trading_Volume': 879212, 'Trading_money': 34415846, 'open': 39.7, 'max': 39.8, 'min': 38.65, 'close': 38.8, 'spread': -0.6, 'Trading_turnover': 1072}
# {'date': '2023-10-06', 'stock_id': '2465', 'Trading_Volume': 4605971, 'Trading_money': 192242530, 'open': 38.9, 'max': 42.65, 'min': 38.9, 'close': 42.65, 'spread': 3.85, 'Trading_turnover': 2535}
# {'date': '2023-10-11', 'stock_id': '2465', 'Trading_Volume': 7147142, 'Trading_money': 323687163, 'open': 45.0, 'max': 46.9, 'min': 43.15, 'close': 46.9, 'spread': 4.25, 'Trading_turnover': 4265}
# {'date': '2023-10-12', 'stock_id': '2465', 'Trading_Volume': 8340333, 'Trading_money': 410506374, 'open': 47.2, 'max': 51.5, 'min': 46.05, 'close': 51.2, 'spread': 4.3, 'Trading_turnover': 5376}
# {'date': '2023-10-13', 'stock_id': '2465', 'Trading_Volume': 6441421, 'Trading_money': 328372372, 'open': 50.0, 'max': 53.6, 'min': 49.05, 'close': 51.5, 'spread': 0.3, 'Trading_turnover': 4596}
# {'date': '2023-10-16', 'stock_id': '2465', 'Trading_Volume': 3304876, 'Trading_money': 167728777, 'open': 50.5, 'max': 52.0, 'min': 49.4, 'close': 51.8, 'spread': 0.3, 'Trading_turnover': 2544}
# {'date': '2023-10-17', 'stock_id': '2465', 'Trading_Volume': 5253603, 'Trading_money': 257020998, 'open': 50.0, 'max': 51.1, 'min': 46.65, 'close': 50.3, 'spread': -1.5, 'Trading_turnover': 3819}
# {'date': '2023-10-18', 'stock_id': '2465', 'Trading_Volume': 3658111, 'Trading_money': 169201213, 'open': 47.5, 'max': 48.4, 'min': 45.3, 'close': 45.3, 'spread': -5.0, 'Trading_turnover': 2793}
# {'date': '2023-10-19', 'stock_id': '2465', 'Trading_Volume': 4226792, 'Trading_money': 181789892, 'open': 45.3, 'max': 45.5, 'min': 40.85, 'close': 42.15, 'spread': -3.15, 'Trading_turnover': 2917}
# {'date': '2023-10-20', 'stock_id': '2465', 'Trading_Volume': 1851900, 'Trading_money': 75626156, 'open': 41.4, 'max': 41.75, 'min': 39.5, 'close': 40.4, 'spread': -1.75, 'Trading_turnover': 1416}
# {'date': '2023-10-23', 'stock_id': '2465', 'Trading_Volume': 1596420, 'Trading_money': 69082726, 'open': 41.35, 'max': 44.4, 'min': 40.6, 'close': 44.4, 'spread': 4.0, 'Trading_turnover': 968}
# {'date': '2023-10-24', 'stock_id': '2465', 'Trading_Volume': 1184941, 'Trading_money': 57825089, 'open': 48.8, 'max': 48.8, 'min': 48.8, 'close': 48.8, 'spread': 4.4, 'Trading_turnover': 708}
# {'date': '2023-10-25', 'stock_id': '2465', 'Trading_Volume': 8769452, 'Trading_money': 468658721, 'open': 53.6, 'max': 53.6, 'min': 52.0, 'close': 53.6, 'spread': 4.8, 'Trading_turnover': 4193}
# {'date': '2023-10-26', 'stock_id': '2465', 'Trading_Volume': 9768620, 'Trading_money': 532408661, 'open': 49.9, 'max': 58.5, 'min': 49.0, 'close': 57.6, 'spread': 4.0, 'Trading_turnover': 6695}
# {'date': '2023-10-27', 'stock_id': '2465', 'Trading_Volume': 6255598, 'Trading_money': 351728364, 'open': 55.1, 'max': 58.5, 'min': 54.0, 'close': 57.0, 'spread': -0.6, 'Trading_turnover': 4612}
# {'date': '2023-10-30', 'stock_id': '2465', 'Trading_Volume': 5058576, 'Trading_money': 277853992, 'open': 56.9, 'max': 57.0, 'min': 52.6, 'close': 55.0, 'spread': -2.0, 'Trading_turnover': 3559}
# {'date': '2023-10-31', 'stock_id': '2465', 'Trading_Volume': 4533976, 'Trading_money': 248860340, 'open': 55.7, 'max': 56.7, 'min': 52.5, 'close': 52.5, 'spread': -2.5, 'Trading_turnover': 3194}
# {'date': '2023-11-01', 'stock_id': '2465', 'Trading_Volume': 1896678, 'Trading_money': 99180330, 'open': 52.5, 'max': 53.8, 'min': 51.1, 'close': 51.6, 'spread': -0.9, 'Trading_turnover': 1729}
# {'date': '2023-11-02', 'stock_id': '2465', 'Trading_Volume': 4217627, 'Trading_money': 230724379, 'open': 53.8, 'max': 56.4, 'min': 52.2, 'close': 55.3, 'spread': 3.7, 'Trading_turnover': 3157}
# {'date': '2023-11-03', 'stock_id': '2465', 'Trading_Volume': 2744241, 'Trading_money': 148637965, 'open': 54.5, 'max': 55.5, 'min': 53.0, 'close': 53.6, 'spread': -1.7, 'Trading_turnover': 2294}
# {'date': '2023-11-06', 'stock_id': '2465', 'Trading_Volume': 2491727, 'Trading_money': 135893291, 'open': 54.0, 'max': 55.3, 'min': 53.5, 'close': 54.3, 'spread': 0.7, 'Trading_turnover': 2129}
# {'date': '2023-11-07', 'stock_id': '2465', 'Trading_Volume': 2216519, 'Trading_money': 118673727, 'open': 54.4, 'max': 55.3, 'min': 52.5, 'close': 52.7, 'spread': -1.6, 'Trading_turnover': 1912}
# {'date': '2023-11-08', 'stock_id': '2465', 'Trading_Volume': 1752727, 'Trading_money': 92176917, 'open': 52.3, 'max': 54.2, 'min': 51.6, 'close': 51.8, 'spread': -0.9, 'Trading_turnover': 1461}
# {'date': '2023-11-09', 'stock_id': '2465', 'Trading_Volume': 5456203, 'Trading_money': 305371249, 'open': 53.4, 'max': 56.9, 'min': 53.4, 'close': 56.9, 'spread': 5.1, 'Trading_turnover': 2991}
# {'date': '2023-11-10', 'stock_id': '2465', 'Trading_Volume': 4316442, 'Trading_money': 237401083, 'open': 56.3, 'max': 56.3, 'min': 53.8, 'close': 54.6, 'spread': -2.3, 'Trading_turnover': 3387}
# {'date': '2023-11-13', 'stock_id': '2465', 'Trading_Volume': 3163409, 'Trading_money': 170406716, 'open': 54.6, 'max': 55.7, 'min': 51.9, 'close': 55.5, 'spread': 0.9, 'Trading_turnover': 2224}
# {'date': '2023-11-14', 'stock_id': '2465', 'Trading_Volume': 4442005, 'Trading_money': 249770877, 'open': 55.8, 'max': 58.0, 'min': 55.1, 'close': 55.5, 'spread': 0.0, 'Trading_turnover': 3058}
# {'date': '2023-11-15', 'stock_id': '2465', 'Trading_Volume': 6727205, 'Trading_money': 394444097, 'open': 56.5, 'max': 61.0, 'min': 55.3, 'close': 60.0, 'spread': 4.5, 'Trading_turnover': 4920}
# {'date': '2023-11-16', 'stock_id': '2465', 'Trading_Volume': 3676505, 'Trading_money': 216872715, 'open': 60.1, 'max': 60.1, 'min': 58.0, 'close': 59.0, 'spread': -1.0, 'Trading_turnover': 4498}
# {'date': '2023-11-17', 'stock_id': '2465', 'Trading_Volume': 3237669, 'Trading_money': 185899255, 'open': 59.0, 'max': 59.1, 'min': 56.4, 'close': 58.0, 'spread': -1.0, 'Trading_turnover': 3055}
# {'date': '2023-11-20', 'stock_id': '2465', 'Trading_Volume': 1580283, 'Trading_money': 91680353, 'open': 58.5, 'max': 58.8, 'min': 57.0, 'close': 58.6, 'spread': 0.6, 'Trading_turnover': 1585}
# {'date': '2023-11-21', 'stock_id': '2465', 'Trading_Volume': 4492691, 'Trading_money': 273041890, 'open': 59.5, 'max': 62.8, 'min': 59.5, 'close': 59.5, 'spread': 0.9, 'Trading_turnover': 3815}
# {'date': '2023-11-22', 'stock_id': '2465', 'Trading_Volume': 2497737, 'Trading_money': 144337110, 'open': 58.3, 'max': 58.5, 'min': 57.0, 'close': 57.7, 'spread': -1.8, 'Trading_turnover': 2404}
# {'date': '2023-11-23', 'stock_id': '2465', 'Trading_Volume': 2412246, 'Trading_money': 136298403, 'open': 58.0, 'max': 58.2, 'min': 55.8, 'close': 55.8, 'spread': -1.9, 'Trading_turnover': 2325}
# {'date': '2023-11-24', 'stock_id': '2465', 'Trading_Volume': 1555585, 'Trading_money': 84788495, 'open': 56.1, 'max': 56.1, 'min': 53.6, 'close': 54.2, 'spread': -1.6, 'Trading_turnover': 1466}
# {'date': '2023-11-27', 'stock_id': '2465', 'Trading_Volume': 1465600, 'Trading_money': 78113372, 'open': 54.8, 'max': 55.0, 'min': 52.6, 'close': 52.6, 'spread': -1.6, 'Trading_turnover': 1294}
# {'date': '2023-11-28', 'stock_id': '2465', 'Trading_Volume': 1224757, 'Trading_money': 65508549, 'open': 53.3, 'max': 54.4, 'min': 52.7, 'close': 54.4, 'spread': 1.8, 'Trading_turnover': 960}
# {'date': '2023-11-29', 'stock_id': '2465', 'Trading_Volume': 7529608, 'Trading_money': 446080085, 'open': 55.5, 'max': 59.8, 'min': 54.5, 'close': 59.8, 'spread': 5.4, 'Trading_turnover': 4875}
# {'date': '2023-11-30', 'stock_id': '2465', 'Trading_Volume': 8325384, 'Trading_money': 519986662, 'open': 59.0, 'max': 64.5, 'min': 58.6, 'close': 63.6, 'spread': 3.8, 'Trading_turnover': 5943}
# {'date': '2023-12-01', 'stock_id': '2465', 'Trading_Volume': 3425005, 'Trading_money': 213408227, 'open': 63.2, 'max': 63.5, 'min': 61.2, 'close': 62.1, 'spread': -1.5, 'Trading_turnover': 3433}
# {'date': '2023-12-04', 'stock_id': '2465', 'Trading_Volume': 4405420, 'Trading_money': 280674810, 'open': 63.4, 'max': 66.0, 'min': 62.4, 'close': 62.5, 'spread': 0.4, 'Trading_turnover': 3300}
# {'date': '2023-12-05', 'stock_id': '2465', 'Trading_Volume': 3763803, 'Trading_money': 241814126, 'open': 62.4, 'max': 66.0, 'min': 62.4, 'close': 63.2, 'spread': 0.7, 'Trading_turnover': 2987}
# {'date': '2023-12-06', 'stock_id': '2465', 'Trading_Volume': 9418328, 'Trading_money': 643376834, 'open': 65.2, 'max': 69.5, 'min': 64.2, 'close': 69.5, 'spread': 6.3, 'Trading_turnover': 7239}
# {'date': '2023-12-07', 'stock_id': '2465', 'Trading_Volume': 5135513, 'Trading_money': 344699718, 'open': 68.0, 'max': 68.8, 'min': 66.1, 'close': 66.7, 'spread': -2.8, 'Trading_turnover': 3746}
# {'date': '2023-12-08', 'stock_id': '2465', 'Trading_Volume': 4351298, 'Trading_money': 285785388, 'open': 65.8, 'max': 68.1, 'min': 64.1, 'close': 65.8, 'spread': -0.9, 'Trading_turnover': 5888}
# {'date': '2023-12-11', 'stock_id': '2465', 'Trading_Volume': 4445708, 'Trading_money': 300747000, 'open': 67.0, 'max': 69.5, 'min': 66.1, 'close': 66.7, 'spread': 0.9, 'Trading_turnover': 3380}
# {'date': '2023-12-12', 'stock_id': '2465', 'Trading_Volume': 2576789, 'Trading_money': 167308332, 'open': 66.1, 'max': 66.7, 'min': 64.0, 'close': 64.9, 'spread': -1.8, 'Trading_turnover': 2272}
# {'date': '2023-12-13', 'stock_id': '2465', 'Trading_Volume': 8582014, 'Trading_money': 601010574, 'open': 66.1, 'max': 71.3, 'min': 66.1, 'close': 70.3, 'spread': 5.4, 'Trading_turnover': 5774}
# {'date': '2023-12-14', 'stock_id': '2465', 'Trading_Volume': 5611602, 'Trading_money': 392955241, 'open': 70.1, 'max': 72.8, 'min': 67.6, 'close': 71.4, 'spread': 1.1, 'Trading_turnover': 6691}
# {'date': '2023-12-15', 'stock_id': '2465', 'Trading_Volume': 3180705, 'Trading_money': 219641961, 'open': 71.8, 'max': 71.8, 'min': 68.0, 'close': 68.0, 'spread': -3.4, 'Trading_turnover': 3085}
# {'date': '2023-12-18', 'stock_id': '2465', 'Trading_Volume': 2045551, 'Trading_money': 140128280, 'open': 67.7, 'max': 69.5, 'min': 66.5, 'close': 69.2, 'spread': 1.2, 'Trading_turnover': 1619}
# {'date': '2023-12-19', 'stock_id': '2465', 'Trading_Volume': 5626807, 'Trading_money': 372334026, 'open': 69.5, 'max': 69.7, 'min': 64.2, 'close': 66.5, 'spread': -2.7, 'Trading_turnover': 5255}
# {'date': '2023-12-20', 'stock_id': '2465', 'Trading_Volume': 1801505, 'Trading_money': 120363134, 'open': 66.0, 'max': 68.0, 'min': 66.0, 'close': 66.3, 'spread': -0.2, 'Trading_turnover': 1480}
# {'date': '2023-12-21', 'stock_id': '2465', 'Trading_Volume': 1189926, 'Trading_money': 78017387, 'open': 65.0, 'max': 66.5, 'min': 64.6, 'close': 65.4, 'spread': -0.9, 'Trading_turnover': 1226}
# {'date': '2023-12-22', 'stock_id': '2465', 'Trading_Volume': 3156760, 'Trading_money': 214418652, 'open': 66.0, 'max': 70.0, 'min': 65.5, 'close': 68.5, 'spread': 3.1, 'Trading_turnover': 2786}
# {'date': '2023-12-25', 'stock_id': '2465', 'Trading_Volume': 1898416, 'Trading_money': 128443723, 'open': 69.0, 'max': 69.5, 'min': 66.9, 'close': 66.9, 'spread': -1.6, 'Trading_turnover': 1914}
# {'date': '2023-12-26', 'stock_id': '2465', 'Trading_Volume': 1552881, 'Trading_money': 105414709, 'open': 66.2, 'max': 68.6, 'min': 66.2, 'close': 68.6, 'spread': 1.7, 'Trading_turnover': 1420}
# {'date': '2023-12-27', 'stock_id': '2465', 'Trading_Volume': 1652154, 'Trading_money': 111716349, 'open': 69.3, 'max': 69.4, 'min': 66.9, 'close': 67.2, 'spread': -1.4, 'Trading_turnover': 1896}
# {'date': '2023-12-28', 'stock_id': '2465', 'Trading_Volume': 2411064, 'Trading_money': 163656296, 'open': 68.6, 'max': 69.4, 'min': 67.0, 'close': 67.2, 'spread': 0.0, 'Trading_turnover': 2030}
# {'date': '2023-12-29', 'stock_id': '2465', 'Trading_Volume': 4423143, 'Trading_money': 283744364, 'open': 67.2, 'max': 67.5, 'min': 62.8, 'close': 63.4, 'spread': -3.8, 'Trading_turnover': 3722}
# {'date': '2024-01-02', 'stock_id': '2465', 'Trading_Volume': 1160461, 'Trading_money': 73300239, 'open': 64.0, 'max': 64.2, 'min': 62.5, 'close': 63.5, 'spread': 0.1, 'Trading_turnover': 1234}
# {'date': '2024-01-03', 'stock_id': '2465', 'Trading_Volume': 934332, 'Trading_money': 58315859, 'open': 63.0, 'max': 63.2, 'min': 62.0, 'close': 62.3, 'spread': -1.2, 'Trading_turnover': 961}
# {'date': '2024-01-04', 'stock_id': '2465', 'Trading_Volume': 1536233, 'Trading_money': 95249686, 'open': 61.9, 'max': 64.0, 'min': 60.8, 'close': 61.0, 'spread': -1.3, 'Trading_turnover': 1121}
# {'date': '2024-01-05', 'stock_id': '2465', 'Trading_Volume': 783570, 'Trading_money': 47909098, 'open': 61.0, 'max': 62.0, 'min': 60.6, 'close': 60.9, 'spread': -0.1, 'Trading_turnover': 872}
# {'date': '2024-01-08', 'stock_id': '2465', 'Trading_Volume': 679341, 'Trading_money': 41453080, 'open': 60.9, 'max': 62.2, 'min': 60.2, 'close': 60.2, 'spread': -0.7, 'Trading_turnover': 718}
# {'date': '2024-01-09', 'stock_id': '2465', 'Trading_Volume': 1546258, 'Trading_money': 96084771, 'open': 63.3, 'max': 63.7, 'min': 60.4, 'close': 60.4, 'spread': 0.2, 'Trading_turnover': 1159}
# {'date': '2024-01-10', 'stock_id': '2465', 'Trading_Volume': 1264886, 'Trading_money': 75505089, 'open': 59.6, 'max': 61.8, 'min': 59.0, 'close': 59.1, 'spread': -1.3, 'Trading_turnover': 1313}
# {'date': '2024-01-11', 'stock_id': '2465', 'Trading_Volume': 2422892, 'Trading_money': 151032058, 'open': 59.5, 'max': 64.7, 'min': 59.5, 'close': 64.4, 'spread': 5.3, 'Trading_turnover': 1916}
# {'date': '2024-01-12', 'stock_id': '2465', 'Trading_Volume': 1746402, 'Trading_money': 108795648, 'open': 64.0, 'max': 64.0, 'min': 61.4, 'close': 61.4, 'spread': -3.0, 'Trading_turnover': 1521}
# {'date': '2024-01-15', 'stock_id': '2465', 'Trading_Volume': 1028941, 'Trading_money': 62383969, 'open': 61.0, 'max': 61.4, 'min': 60.0, 'close': 60.8, 'spread': -0.6, 'Trading_turnover': 887}
# {'date': '2024-01-16', 'stock_id': '2465', 'Trading_Volume': 1397218, 'Trading_money': 83052409, 'open': 60.8, 'max': 60.8, 'min': 59.0, 'close': 59.1, 'spread': -1.7, 'Trading_turnover': 1146}
# {'date': '2024-01-17', 'stock_id': '2465', 'Trading_Volume': 1165538, 'Trading_money': 67345718, 'open': 59.5, 'max': 59.8, 'min': 56.1, 'close': 56.7, 'spread': -2.4, 'Trading_turnover': 1114}
# {'date': '2024-01-18', 'stock_id': '2465', 'Trading_Volume': 711380, 'Trading_money': 40255410, 'open': 56.7, 'max': 57.7, 'min': 55.5, 'close': 56.2, 'spread': -0.5, 'Trading_turnover': 620}
# {'date': '2024-01-19', 'stock_id': '2465', 'Trading_Volume': 2760959, 'Trading_money': 167256935, 'open': 57.3, 'max': 61.7, 'min': 57.3, 'close': 61.5, 'spread': 5.3, 'Trading_turnover': 2233}
# {'date': '2024-01-22', 'stock_id': '2465', 'Trading_Volume': 7452621, 'Trading_money': 491618364, 'open': 66.0, 'max': 67.6, 'min': 63.1, 'close': 67.6, 'spread': 6.1, 'Trading_turnover': 5260}
# {'date': '2024-01-23', 'stock_id': '2465', 'Trading_Volume': 8527265, 'Trading_money': 590321838, 'open': 66.9, 'max': 71.5, 'min': 65.5, 'close': 71.0, 'spread': 3.4, 'Trading_turnover': 6007}
# {'date': '2024-01-24', 'stock_id': '2465', 'Trading_Volume': 3449904, 'Trading_money': 240884741, 'open': 70.5, 'max': 71.0, 'min': 69.1, 'close': 69.2, 'spread': -1.8, 'Trading_turnover': 4577}
# {'date': '2024-01-25', 'stock_id': '2465', 'Trading_Volume': 2996753, 'Trading_money': 210471988, 'open': 70.5, 'max': 71.2, 'min': 69.4, 'close': 69.6, 'spread': 0.4, 'Trading_turnover': 2878}
# {'date': '2024-01-26', 'stock_id': '2465', 'Trading_Volume': 2503273, 'Trading_money': 170105029, 'open': 68.9, 'max': 69.7, 'min': 66.7, 'close': 66.7, 'spread': -2.9, 'Trading_turnover': 4416}
# {'date': '2024-01-29', 'stock_id': '2465', 'Trading_Volume': 1509320, 'Trading_money': 100974414, 'open': 66.7, 'max': 68.2, 'min': 66.0, 'close': 66.3, 'spread': -0.4, 'Trading_turnover': 1734}
# {'date': '2024-01-30', 'stock_id': '2465', 'Trading_Volume': 9143062, 'Trading_money': 654976465, 'open': 68.8, 'max': 72.9, 'min': 68.6, 'close': 72.9, 'spread': 6.6, 'Trading_turnover': 6738}
# {'date': '2024-01-31', 'stock_id': '2465', 'Trading_Volume': 11076770, 'Trading_money': 829029710, 'open': 72.2, 'max': 79.0, 'min': 71.1, 'close': 78.0, 'spread': 5.1, 'Trading_turnover': 8205}
# {'date': '2024-02-01', 'stock_id': '2465', 'Trading_Volume': 7136156, 'Trading_money': 554864420, 'open': 76.5, 'max': 80.0, 'min': 75.2, 'close': 78.1, 'spread': 0.1, 'Trading_turnover': 5430}
# {'date': '2024-02-02', 'stock_id': '2465', 'Trading_Volume': 7512699, 'Trading_money': 632180503, 'open': 80.4, 'max': 85.9, 'min': 80.0, 'close': 85.9, 'spread': 7.8, 'Trading_turnover': 6496}
# {'date': '2024-02-05', 'stock_id': '2465', 'Trading_Volume': 8175111, 'Trading_money': 762326135, 'open': 92.0, 'max': 94.4, 'min': 88.8, 'close': 94.4, 'spread': 8.5, 'Trading_turnover': 7388}
# {'date': '2024-02-15', 'stock_id': '2465', 'Trading_Volume': 1466362, 'Trading_money': 151768360, 'open': 103.5, 'max': 103.5, 'min': 103.5, 'close': 103.5, 'spread': 9.1, 'Trading_turnover': 1313}
# {'date': '2024-02-16', 'stock_id': '2465', 'Trading_Volume': 1003745, 'Trading_money': 113925003, 'open': 113.5, 'max': 113.5, 'min': 113.5, 'close': 113.5, 'spread': 10.0, 'Trading_turnover': 837}
# {'date': '2024-02-19', 'stock_id': '2465', 'Trading_Volume': 7893222, 'Trading_money': 866262653, 'open': 102.5, 'max': 124.0, 'min': 102.5, 'close': 123.5, 'spread': 10.0, 'Trading_turnover': 6834}
# {'date': '2024-02-20', 'stock_id': '2465', 'Trading_Volume': 4241649, 'Trading_money': 521502594, 'open': 118.0, 'max': 128.5, 'min': 117.0, 'close': 121.5, 'spread': -2.0, 'Trading_turnover': 4713}
# {'date': '2024-02-21', 'stock_id': '2465', 'Trading_Volume': 3202414, 'Trading_money': 383177699, 'open': 121.0, 'max': 124.5, 'min': 115.0, 'close': 120.0, 'spread': -1.5, 'Trading_turnover': 3407}
# {'date': '2024-02-22', 'stock_id': '2465', 'Trading_Volume': 1554186, 'Trading_money': 182873177, 'open': 124.0, 'max': 124.0, 'min': 115.5, 'close': 119.5, 'spread': -0.5, 'Trading_turnover': 1350}
# {'date': '2024-02-23', 'stock_id': '2465', 'Trading_Volume': 1415656, 'Trading_money': 172447895, 'open': 124.0, 'max': 124.0, 'min': 117.0, 'close': 123.0, 'spread': 3.5, 'Trading_turnover': 1366}
# {'date': '2024-02-26', 'stock_id': '2465', 'Trading_Volume': 1126561, 'Trading_money': 139908667, 'open': 123.0, 'max': 126.0, 'min': 121.0, 'close': 126.0, 'spread': 3.0, 'Trading_turnover': 1157}
# {'date': '2024-02-27', 'stock_id': '2465', 'Trading_Volume': 1940292, 'Trading_money': 253665136, 'open': 129.0, 'max': 133.0, 'min': 126.0, 'close': 133.0, 'spread': 7.0, 'Trading_turnover': 1669}
# {'date': '2024-02-29', 'stock_id': '2465', 'Trading_Volume': 2637315, 'Trading_money': 382406625, 'open': 138.0, 'max': 146.0, 'min': 138.0, 'close': 144.0, 'spread': 11.0, 'Trading_turnover': 1791}
# {'date': '2024-03-01', 'stock_id': '2465', 'Trading_Volume': 1177288, 'Trading_money': 167322998, 'open': 142.5, 'max': 146.0, 'min': 140.0, 'close': 146.0, 'spread': 2.0, 'Trading_turnover': 1110}
# {'date': '2024-03-04', 'stock_id': '2465', 'Trading_Volume': 1604113, 'Trading_money': 255992090, 'open': 160.5, 'max': 160.5, 'min': 155.5, 'close': 160.0, 'spread': 14.0, 'Trading_turnover': 1474}
# {'date': '2024-03-05', 'stock_id': '2465', 'Trading_Volume': 1575577, 'Trading_money': 254717318, 'open': 173.0, 'max': 173.0, 'min': 154.5, 'close': 157.0, 'spread': -3.0, 'Trading_turnover': 1721}
# {'date': '2024-03-06', 'stock_id': '2465', 'Trading_Volume': 1452303, 'Trading_money': 222234664, 'open': 155.0, 'max': 157.0, 'min': 150.0, 'close': 157.0, 'spread': 0.0, 'Trading_turnover': 1388}
# {'date': '2024-03-07', 'stock_id': '2465', 'Trading_Volume': 2152734, 'Trading_money': 327119853, 'open': 161.0, 'max': 163.5, 'min': 146.0, 'close': 148.0, 'spread': -9.0, 'Trading_turnover': 1780}
# {'date': '2024-03-08', 'stock_id': '2465', 'Trading_Volume': 7550301, 'Trading_money': 1025026624, 'open': 146.0, 'max': 146.0, 'min': 133.5, 'close': 133.5, 'spread': -14.5, 'Trading_turnover': 7837}
# {'date': '2024-03-11', 'stock_id': '2465', 'Trading_Volume': 5313608, 'Trading_money': 689665222, 'open': 128.5, 'max': 136.5, 'min': 125.0, 'close': 130.0, 'spread': -3.5, 'Trading_turnover': 7513}
# {'date': '2024-03-12', 'stock_id': '2465', 'Trading_Volume': 4533564, 'Trading_money': 623067860, 'open': 132.0, 'max': 143.0, 'min': 128.0, 'close': 143.0, 'spread': 13.0, 'Trading_turnover': 3918}
# {'date': '2024-03-13', 'stock_id': '2465', 'Trading_Volume': 7211708, 'Trading_money': 1059043509, 'open': 147.5, 'max': 152.5, 'min': 141.0, 'close': 145.0, 'spread': 2.0, 'Trading_turnover': 6272}
# {'date': '2024-03-14', 'stock_id': '2465', 'Trading_Volume': 4679599, 'Trading_money': 628435516, 'open': 140.0, 'max': 142.5, 'min': 130.5, 'close': 132.0, 'spread': -13.0, 'Trading_turnover': 4379}
# {'date': '2024-03-15', 'stock_id': '2465', 'Trading_Volume': 3445045, 'Trading_money': 441228798, 'open': 129.0, 'max': 133.5, 'min': 125.0, 'close': 125.5, 'spread': -6.5, 'Trading_turnover': 3085}
# {'date': '2024-03-18', 'stock_id': '2465', 'Trading_Volume': 3085567, 'Trading_money': 405344202, 'open': 124.5, 'max': 137.0, 'min': 124.5, 'close': 132.5, 'spread': 7.0, 'Trading_turnover': 2623}
# {'date': '2024-03-19', 'stock_id': '2465', 'Trading_Volume': 2686921, 'Trading_money': 346783944, 'open': 130.0, 'max': 135.5, 'min': 125.0, 'close': 129.0, 'spread': -3.5, 'Trading_turnover': 2688}
# {'date': '2024-03-20', 'stock_id': '2465', 'Trading_Volume': 3411204, 'Trading_money': 428784929, 'open': 128.0, 'max': 130.0, 'min': 121.0, 'close': 124.5, 'spread': -4.5, 'Trading_turnover': 2723}
# {'date': '2024-03-21', 'stock_id': '2465', 'Trading_Volume': 3784821, 'Trading_money': 463048332, 'open': 127.5, 'max': 128.0, 'min': 118.5, 'close': 120.0, 'spread': -4.5, 'Trading_turnover': 3423}
# {'date': '2024-03-22', 'stock_id': '2465', 'Trading_Volume': 3242466, 'Trading_money': 389633889, 'open': 123.5, 'max': 126.0, 'min': 116.0, 'close': 117.5, 'spread': -2.5, 'Trading_turnover': 2917}
# {'date': '2024-03-25', 'stock_id': '2465', 'Trading_Volume': 3268024, 'Trading_money': 372029244, 'open': 116.5, 'max': 119.0, 'min': 112.0, 'close': 112.5, 'spread': -5.0, 'Trading_turnover': 3306}
# {'date': '2024-03-26', 'stock_id': '2465', 'Trading_Volume': 4666129, 'Trading_money': 558986707, 'open': 116.0, 'max': 123.5, 'min': 113.0, 'close': 123.5, 'spread': 11.0, 'Trading_turnover': 3681}
# {'date': '2024-03-27', 'stock_id': '2465', 'Trading_Volume': 5118475, 'Trading_money': 621664542, 'open': 125.5, 'max': 126.0, 'min': 116.5, 'close': 117.5, 'spread': -6.0, 'Trading_turnover': 4221}
# {'date': '2024-03-28', 'stock_id': '2465', 'Trading_Volume': 2143612, 'Trading_money': 245730342, 'open': 115.0, 'max': 117.0, 'min': 113.0, 'close': 114.5, 'spread': -3.0, 'Trading_turnover': 2250}
# {'date': '2024-03-29', 'stock_id': '2465', 'Trading_Volume': 3408830, 'Trading_money': 407771020, 'open': 117.0, 'max': 122.5, 'min': 116.0, 'close': 120.5, 'spread': 6.0, 'Trading_turnover': 3141}
# {'date': '2024-04-01', 'stock_id': '2465', 'Trading_Volume': 2786788, 'Trading_money': 340999113, 'open': 121.0, 'max': 124.5, 'min': 120.0, 'close': 123.0, 'spread': 2.5, 'Trading_turnover': 4167}
# {'date': '2024-04-02', 'stock_id': '2465', 'Trading_Volume': 2394925, 'Trading_money': 291260431, 'open': 123.0, 'max': 125.0, 'min': 119.0, 'close': 120.0, 'spread': -3.0, 'Trading_turnover': 2112}
# {'date': '2024-04-03', 'stock_id': '2465', 'Trading_Volume': 2968886, 'Trading_money': 364047857, 'open': 114.0, 'max': 127.5, 'min': 114.0, 'close': 125.0, 'spread': 5.0, 'Trading_turnover': 2840}
# {'date': '2024-04-08', 'stock_id': '2465', 'Trading_Volume': 1917740, 'Trading_money': 237798690, 'open': 125.0, 'max': 126.0, 'min': 122.0, 'close': 124.5, 'spread': -0.5, 'Trading_turnover': 2103}
# {'date': '2024-04-09', 'stock_id': '2465', 'Trading_Volume': 1524271, 'Trading_money': 186901402, 'open': 125.0, 'max': 126.0, 'min': 121.0, 'close': 121.0, 'spread': -3.5, 'Trading_turnover': 1679}
# {'date': '2024-04-10', 'stock_id': '2465', 'Trading_Volume': 1264663, 'Trading_money': 154560366, 'open': 120.0, 'max': 124.0, 'min': 120.0, 'close': 121.5, 'spread': 0.5, 'Trading_turnover': 1484}
# {'date': '2024-04-11', 'stock_id': '2465', 'Trading_Volume': 12255175, 'Trading_money': 1587544456, 'open': 123.0, 'max': 133.5, 'min': 118.5, 'close': 128.5, 'spread': 7.0, 'Trading_turnover': 8784}
# {'date': '2024-04-12', 'stock_id': '2465', 'Trading_Volume': 11453549, 'Trading_money': 1565669584, 'open': 132.5, 'max': 140.5, 'min': 131.0, 'close': 138.0, 'spread': 9.5, 'Trading_turnover': 9399}
# {'date': '2024-04-15', 'stock_id': '2465', 'Trading_Volume': 11231182, 'Trading_money': 1569059084, 'open': 136.0, 'max': 146.5, 'min': 132.0, 'close': 134.5, 'spread': -3.5, 'Trading_turnover': 9163}
# {'date': '2024-04-16', 'stock_id': '2465', 'Trading_Volume': 7486151, 'Trading_money': 938586041, 'open': 130.0, 'max': 131.5, 'min': 122.0, 'close': 122.5, 'spread': -12.0, 'Trading_turnover': 8053}
# {'date': '2024-04-17', 'stock_id': '2465', 'Trading_Volume': 3456139, 'Trading_money': 459217087, 'open': 128.5, 'max': 134.5, 'min': 128.5, 'close': 134.5, 'spread': 12.0, 'Trading_turnover': 2360}
# {'date': '2024-04-18', 'stock_id': '2465', 'Trading_Volume': 16355429, 'Trading_money': 2304989389, 'open': 136.0, 'max': 145.0, 'min': 134.0, 'close': 142.0, 'spread': 7.5, 'Trading_turnover': 12890}
# {'date': '2024-04-19', 'stock_id': '2465', 'Trading_Volume': 15890099, 'Trading_money': 2200453058, 'open': 140.0, 'max': 146.5, 'min': 130.0, 'close': 138.0, 'spread': -4.0, 'Trading_turnover': 12191}
# {'date': '2024-04-22', 'stock_id': '2465', 'Trading_Volume': 6967276, 'Trading_money': 875482873, 'open': 124.5, 'max': 129.5, 'min': 124.5, 'close': 124.5, 'spread': -13.5, 'Trading_turnover': 7063}
# {'date': '2024-04-23', 'stock_id': '2465', 'Trading_Volume': 8011302, 'Trading_money': 965260061, 'open': 125.5, 'max': 128.0, 'min': 115.5, 'close': 121.0, 'spread': -3.5, 'Trading_turnover': 6139}
# {'date': '2024-04-24', 'stock_id': '2465', 'Trading_Volume': 6923463, 'Trading_money': 890645837, 'open': 127.5, 'max': 132.5, 'min': 125.0, 'close': 126.0, 'spread': 5.0, 'Trading_turnover': 5567}
# {'date': '2024-04-25', 'stock_id': '2465', 'Trading_Volume': 3009317, 'Trading_money': 370922675, 'open': 121.5, 'max': 127.0, 'min': 120.0, 'close': 124.0, 'spread': -2.0, 'Trading_turnover': 2741}
# {'date': '2024-04-26', 'stock_id': '2465', 'Trading_Volume': 3943094, 'Trading_money': 493042809, 'open': 129.0, 'max': 129.5, 'min': 121.5, 'close': 122.5, 'spread': -1.5, 'Trading_turnover': 3420}
# {'date': '2024-04-29', 'stock_id': '2465', 'Trading_Volume': 4294127, 'Trading_money': 531442024, 'open': 127.5, 'max': 128.0, 'min': 120.5, 'close': 124.0, 'spread': 1.5, 'Trading_turnover': 3478}
# {'date': '2024-04-30', 'stock_id': '2465', 'Trading_Volume': 6700454, 'Trading_money': 865744897, 'open': 127.5, 'max': 133.0, 'min': 124.5, 'close': 131.5, 'spread': 7.5, 'Trading_turnover': 5628}
# {'date': '2024-05-02', 'stock_id': '2465', 'Trading_Volume': 5493967, 'Trading_money': 677667062, 'open': 123.0, 'max': 125.5, 'min': 121.0, 'close': 124.0, 'spread': -7.5, 'Trading_turnover': 4216}
# {'date': '2024-05-03', 'stock_id': '2465', 'Trading_Volume': 3475326, 'Trading_money': 428455425, 'open': 126.0, 'max': 127.0, 'min': 121.0, 'close': 123.5, 'spread': -0.5, 'Trading_turnover': 4376}
# {'date': '2024-05-06', 'stock_id': '2465', 'Trading_Volume': 2381845, 'Trading_money': 289939421, 'open': 123.5, 'max': 125.0, 'min': 120.0, 'close': 122.0, 'spread': -1.5, 'Trading_turnover': 2352}
# {'date': '2024-05-07', 'stock_id': '2465', 'Trading_Volume': 5982715, 'Trading_money': 756774948, 'open': 122.0, 'max': 131.0, 'min': 121.0, 'close': 130.0, 'spread': 8.0, 'Trading_turnover': 4613}
# {'date': '2024-05-08', 'stock_id': '2465', 'Trading_Volume': 4423342, 'Trading_money': 556986607, 'open': 129.0, 'max': 129.0, 'min': 124.0, 'close': 125.5, 'spread': -4.5, 'Trading_turnover': 3884}
# {'date': '2024-05-09', 'stock_id': '2465', 'Trading_Volume': 2506963, 'Trading_money': 306686831, 'open': 123.0, 'max': 125.0, 'min': 121.0, 'close': 121.0, 'spread': -4.5, 'Trading_turnover': 2151}
# {'date': '2024-05-10', 'stock_id': '2465', 'Trading_Volume': 2679649, 'Trading_money': 318320623, 'open': 121.5, 'max': 123.0, 'min': 116.5, 'close': 118.5, 'spread': -2.5, 'Trading_turnover': 2549}
# {'date': '2024-05-13', 'stock_id': '2465', 'Trading_Volume': 1761906, 'Trading_money': 203796554, 'open': 117.0, 'max': 118.0, 'min': 114.0, 'close': 115.0, 'spread': -3.5, 'Trading_turnover': 1619}
# {'date': '2024-05-14', 'stock_id': '2465', 'Trading_Volume': 1706802, 'Trading_money': 197678606, 'open': 114.0, 'max': 118.0, 'min': 113.5, 'close': 118.0, 'spread': 3.0, 'Trading_turnover': 1604}
# {'date': '2024-05-15', 'stock_id': '2465', 'Trading_Volume': 2472843, 'Trading_money': 297301306, 'open': 119.0, 'max': 122.5, 'min': 118.0, 'close': 121.0, 'spread': 3.0, 'Trading_turnover': 2257}
# {'date': '2024-05-16', 'stock_id': '2465', 'Trading_Volume': 6983437, 'Trading_money': 882385382, 'open': 126.5, 'max': 132.0, 'min': 121.5, 'close': 122.5, 'spread': 1.5, 'Trading_turnover': 5329}
# {'date': '2024-05-17', 'stock_id': '2465', 'Trading_Volume': 1519621, 'Trading_money': 184599841, 'open': 121.5, 'max': 123.0, 'min': 120.0, 'close': 121.5, 'spread': 1.0, 'Trading_turnover': 2009}
# {'date': '2024-05-20', 'stock_id': '2465', 'Trading_Volume': 2208650, 'Trading_money': 265438350, 'open': 122.0, 'max': 123.5, 'min': 118.0, 'close': 119.0, 'spread': -2.5, 'Trading_turnover': 1945}
# {'date': '2024-05-21', 'stock_id': '2465', 'Trading_Volume': 6304437, 'Trading_money': 786808585, 'open': 122.5, 'max': 127.5, 'min': 121.0, 'close': 124.0, 'spread': 5.0, 'Trading_turnover': 4871}
# {'date': '2024-05-22', 'stock_id': '2465', 'Trading_Volume': 9322971, 'Trading_money': 1207670161, 'open': 123.0, 'max': 133.0, 'min': 123.0, 'close': 130.5, 'spread': 6.5, 'Trading_turnover': 6974}
# {'date': '2024-05-23', 'stock_id': '2465', 'Trading_Volume': 11810694, 'Trading_money': 1534010739, 'open': 133.0, 'max': 137.5, 'min': 125.0, 'close': 126.5, 'spread': -4.0, 'Trading_turnover': 8702}
# {'date': '2024-05-24', 'stock_id': '2465', 'Trading_Volume': 3017356, 'Trading_money': 373085540, 'open': 124.5, 'max': 126.5, 'min': 122.5, 'close': 122.5, 'spread': -4.0, 'Trading_turnover': 2565}
# {'date': '2024-05-27', 'stock_id': '2465', 'Trading_Volume': 4026002, 'Trading_money': 513818938, 'open': 125.0, 'max': 131.5, 'min': 123.0, 'close': 128.0, 'spread': 5.5, 'Trading_turnover': 3313}
# {'date': '2024-05-28', 'stock_id': '2465', 'Trading_Volume': 3284059, 'Trading_money': 418911134, 'open': 129.0, 'max': 132.0, 'min': 124.5, 'close': 125.0, 'spread': -3.0, 'Trading_turnover': 2921}
# {'date': '2024-05-29', 'stock_id': '2465', 'Trading_Volume': 2565207, 'Trading_money': 324473999, 'open': 124.5, 'max': 129.0, 'min': 123.5, 'close': 129.0, 'spread': 4.0, 'Trading_turnover': 2137}
# {'date': '2024-05-30', 'stock_id': '2465', 'Trading_Volume': 8216730, 'Trading_money': 1056957347, 'open': 127.0, 'max': 133.0, 'min': 124.0, 'close': 124.5, 'spread': -4.5, 'Trading_turnover': 6461}
# {'date': '2024-05-31', 'stock_id': '2465', 'Trading_Volume': 2660249, 'Trading_money': 337377829, 'open': 125.5, 'max': 129.0, 'min': 125.0, 'close': 125.0, 'spread': 0.5, 'Trading_turnover': 2680}
# {'date': '2024-06-03', 'stock_id': '2465', 'Trading_Volume': 9814976, 'Trading_money': 1319074162, 'open': 131.0, 'max': 137.5, 'min': 129.5, 'close': 137.5, 'spread': 12.5, 'Trading_turnover': 7004}
# {'date': '2024-06-04', 'stock_id': '2465', 'Trading_Volume': 35604021, 'Trading_money': 4975002541, 'open': 141.5, 'max': 148.5, 'min': 127.0, 'close': 128.0, 'spread': -9.5, 'Trading_turnover': 26671}
# {'date': '2024-06-05', 'stock_id': '2465', 'Trading_Volume': 6178946, 'Trading_money': 794915768, 'open': 129.0, 'max': 132.0, 'min': 126.5, 'close': 127.5, 'spread': -0.5, 'Trading_turnover': 4919}
# {'date': '2024-06-06', 'stock_id': '2465', 'Trading_Volume': 4108120, 'Trading_money': 533266759, 'open': 131.5, 'max': 132.0, 'min': 127.0, 'close': 130.5, 'spread': 3.0, 'Trading_turnover': 3329}
# {'date': '2024-06-07', 'stock_id': '2465', 'Trading_Volume': 2693416, 'Trading_money': 344607600, 'open': 130.5, 'max': 131.0, 'min': 126.5, 'close': 126.5, 'spread': -4.0, 'Trading_turnover': 2657}
# {'date': '2024-06-11', 'stock_id': '2465', 'Trading_Volume': 2234776, 'Trading_money': 278477224, 'open': 126.0, 'max': 128.0, 'min': 123.0, 'close': 123.0, 'spread': -3.5, 'Trading_turnover': 2060}
# {'date': '2024-06-12', 'stock_id': '2465', 'Trading_Volume': 2269003, 'Trading_money': 284766238, 'open': 123.0, 'max': 129.0, 'min': 122.5, 'close': 128.0, 'spread': 5.0, 'Trading_turnover': 1970}
# {'date': '2024-06-13', 'stock_id': '2465', 'Trading_Volume': 3554664, 'Trading_money': 456221790, 'open': 129.0, 'max': 131.5, 'min': 126.0, 'close': 129.0, 'spread': 1.0, 'Trading_turnover': 3197}
# {'date': '2024-06-14', 'stock_id': '2465', 'Trading_Volume': 4279183, 'Trading_money': 558829358, 'open': 132.0, 'max': 134.5, 'min': 128.0, 'close': 128.5, 'spread': -0.5, 'Trading_turnover': 3700}
# {'date': '2024-06-17', 'stock_id': '2465', 'Trading_Volume': 1485417, 'Trading_money': 187790701, 'open': 127.5, 'max': 128.5, 'min': 125.5, 'close': 125.5, 'spread': -3.0, 'Trading_turnover': 1502}
# {'date': '2024-06-18', 'stock_id': '2465', 'Trading_Volume': 1224787, 'Trading_money': 154600744, 'open': 126.5, 'max': 128.5, 'min': 125.0, 'close': 126.0, 'spread': 0.5, 'Trading_turnover': 1243}
# {'date': '2024-06-19', 'stock_id': '2465', 'Trading_Volume': 2535518, 'Trading_money': 324014284, 'open': 127.5, 'max': 130.5, 'min': 126.0, 'close': 128.0, 'spread': 2.0, 'Trading_turnover': 2200}
# {'date': '2024-06-20', 'stock_id': '2465', 'Trading_Volume': 1925419, 'Trading_money': 243933034, 'open': 128.0, 'max': 129.0, 'min': 126.0, 'close': 126.0, 'spread': -2.0, 'Trading_turnover': 1939}
# {'date': '2024-06-21', 'stock_id': '2465', 'Trading_Volume': 1365590, 'Trading_money': 170639575, 'open': 126.0, 'max': 126.5, 'min': 123.5, 'close': 124.5, 'spread': -1.5, 'Trading_turnover': 1319}
# {'date': '2024-06-24', 'stock_id': '2465', 'Trading_Volume': 1840847, 'Trading_money': 224675402, 'open': 123.0, 'max': 125.0, 'min': 121.5, 'close': 121.5, 'spread': -3.0, 'Trading_turnover': 1893}
# {'date': '2024-06-25', 'stock_id': '2465', 'Trading_Volume': 1349487, 'Trading_money': 161585442, 'open': 120.0, 'max': 122.5, 'min': 117.5, 'close': 122.5, 'spread': 1.0, 'Trading_turnover': 1302}
# {'date': '2024-06-26', 'stock_id': '2465', 'Trading_Volume': 1374414, 'Trading_money': 170308507, 'open': 122.0, 'max': 125.5, 'min': 122.0, 'close': 125.0, 'spread': 2.5, 'Trading_turnover': 1272}
# {'date': '2024-06-27', 'stock_id': '2465', 'Trading_Volume': 3604017, 'Trading_money': 458710467, 'open': 126.0, 'max': 129.5, 'min': 125.0, 'close': 126.5, 'spread': 1.5, 'Trading_turnover': 2881}
# {'date': '2024-06-28', 'stock_id': '2465', 'Trading_Volume': 1550826, 'Trading_money': 194820660, 'open': 127.5, 'max': 128.0, 'min': 124.0, 'close': 124.0, 'spread': -2.5, 'Trading_turnover': 1483}
# {'date': '2024-07-01', 'stock_id': '2465', 'Trading_Volume': 863785, 'Trading_money': 106553233, 'open': 125.0, 'max': 125.5, 'min': 122.5, 'close': 122.5, 'spread': -1.5, 'Trading_turnover': 897}
# {'date': '2024-07-02', 'stock_id': '2465', 'Trading_Volume': 1262610, 'Trading_money': 153420862, 'open': 122.5, 'max': 124.0, 'min': 120.0, 'close': 121.0, 'spread': -1.5, 'Trading_turnover': 1156}
# {'date': '2024-07-03', 'stock_id': '2465', 'Trading_Volume': 764704, 'Trading_money': 93025561, 'open': 122.0, 'max': 123.0, 'min': 121.0, 'close': 121.0, 'spread': 0.0, 'Trading_turnover': 814}
# {'date': '2024-07-04', 'stock_id': '2465', 'Trading_Volume': 954315, 'Trading_money': 116546748, 'open': 121.5, 'max': 123.0, 'min': 121.0, 'close': 122.5, 'spread': 1.5, 'Trading_turnover': 853}
# {'date': '2024-07-05', 'stock_id': '2465', 'Trading_Volume': 1516361, 'Trading_money': 187362680, 'open': 123.0, 'max': 126.0, 'min': 122.0, 'close': 122.5, 'spread': 0.0, 'Trading_turnover': 1342}
# {'date': '2024-07-08', 'stock_id': '2465', 'Trading_Volume': 925144, 'Trading_money': 112382513, 'open': 123.0, 'max': 124.0, 'min': 120.5, 'close': 120.5, 'spread': -2.0, 'Trading_turnover': 934}
# {'date': '2024-07-09', 'stock_id': '2465', 'Trading_Volume': 1434455, 'Trading_money': 170301309, 'open': 120.0, 'max': 121.0, 'min': 118.0, 'close': 118.5, 'spread': -2.0, 'Trading_turnover': 1411}
# {'date': '2024-07-10', 'stock_id': '2465', 'Trading_Volume': 955669, 'Trading_money': 112764824, 'open': 118.5, 'max': 119.5, 'min': 117.0, 'close': 117.0, 'spread': -1.5, 'Trading_turnover': 1042}
# {'date': '2024-07-11', 'stock_id': '2465', 'Trading_Volume': 2147637, 'Trading_money': 247404468, 'open': 117.5, 'max': 118.5, 'min': 113.5, 'close': 114.0, 'spread': -3.0, 'Trading_turnover': 2090}
# {'date': '2024-07-12', 'stock_id': '2465', 'Trading_Volume': 1352953, 'Trading_money': 153080348, 'open': 112.5, 'max': 115.5, 'min': 111.0, 'close': 112.5, 'spread': -1.5, 'Trading_turnover': 1372}
# {'date': '2024-07-15', 'stock_id': '2465', 'Trading_Volume': 3041428, 'Trading_money': 372728327, 'open': 118.0, 'max': 123.5, 'min': 118.0, 'close': 123.5, 'spread': 11.0, 'Trading_turnover': 1862}
# {'date': '2024-07-16', 'stock_id': '2465', 'Trading_Volume': 8733462, 'Trading_money': 1104130658, 'open': 127.0, 'max': 129.0, 'min': 125.0, 'close': 125.0, 'spread': 1.5, 'Trading_turnover': 6739}
# {'date': '2024-07-17', 'stock_id': '2465', 'Trading_Volume': 2248516, 'Trading_money': 278025332, 'open': 124.5, 'max': 126.0, 'min': 121.5, 'close': 123.5, 'spread': -1.5, 'Trading_turnover': 2127}
# {'date': '2024-07-18', 'stock_id': '2465', 'Trading_Volume': 1673804, 'Trading_money': 200395802, 'open': 121.0, 'max': 122.0, 'min': 118.0, 'close': 118.5, 'spread': -5.0, 'Trading_turnover': 1551}
# {'date': '2024-07-19', 'stock_id': '2465', 'Trading_Volume': 1237297, 'Trading_money': 147853725, 'open': 119.0, 'max': 121.5, 'min': 118.0, 'close': 118.5, 'spread': 0.0, 'Trading_turnover': 1147}
# {'date': '2024-07-22', 'stock_id': '2465', 'Trading_Volume': 1665731, 'Trading_money': 196947080, 'open': 121.0, 'max': 123.0, 'min': 116.0, 'close': 116.5, 'spread': -2.0, 'Trading_turnover': 1504}
# {'date': '2024-07-23', 'stock_id': '2465', 'Trading_Volume': 1026535, 'Trading_money': 118838490, 'open': 117.0, 'max': 118.0, 'min': 114.5, 'close': 115.0, 'spread': -1.5, 'Trading_turnover': 1023}
# {'date': '2024-07-26', 'stock_id': '2465', 'Trading_Volume': 1372084, 'Trading_money': 150685008, 'open': 111.0, 'max': 112.0, 'min': 108.5, 'close': 110.0, 'spread': -5.0, 'Trading_turnover': 1238}
# {'date': '2024-07-29', 'stock_id': '2465', 'Trading_Volume': 2305401, 'Trading_money': 242800754, 'open': 113.0, 'max': 113.5, 'min': 101.0, 'close': 101.0, 'spread': -9.0, 'Trading_turnover': 2486}
# {'date': '2024-07-30', 'stock_id': '2465', 'Trading_Volume': 2076399, 'Trading_money': 209215285, 'open': 99.9, 'max': 105.5, 'min': 98.2, 'close': 104.0, 'spread': 3.0, 'Trading_turnover': 1895}
# {'date': '2024-07-31', 'stock_id': '2465', 'Trading_Volume': 563751, 'Trading_money': 57736379, 'open': 102.5, 'max': 104.0, 'min': 101.0, 'close': 102.5, 'spread': -1.5, 'Trading_turnover': 699}
# {'date': '2024-08-01', 'stock_id': '2465', 'Trading_Volume': 769745, 'Trading_money': 80415932, 'open': 105.5, 'max': 106.0, 'min': 103.0, 'close': 104.5, 'spread': 2.0, 'Trading_turnover': 742}
# {'date': '2024-08-02', 'stock_id': '2465', 'Trading_Volume': 1231771, 'Trading_money': 122538348, 'open': 101.0, 'max': 101.5, 'min': 97.5, 'close': 98.4, 'spread': -6.1, 'Trading_turnover': 1221}
# {'date': '2024-08-05', 'stock_id': '2465', 'Trading_Volume': 1021232, 'Trading_money': 90773566, 'open': 89.0, 'max': 91.5, 'min': 88.6, 'close': 88.6, 'spread': -9.8, 'Trading_turnover': 1135}
# {'date': '2024-08-06', 'stock_id': '2465', 'Trading_Volume': 3264105, 'Trading_money': 269522019, 'open': 87.0, 'max': 89.9, 'min': 79.8, 'close': 83.1, 'spread': -5.5, 'Trading_turnover': 2491}
# {'date': '2024-08-07', 'stock_id': '2465', 'Trading_Volume': 1678637, 'Trading_money': 150527860, 'open': 84.5, 'max': 91.4, 'min': 83.6, 'close': 91.4, 'spread': 8.3, 'Trading_turnover': 1168}
# {'date': '2024-08-08', 'stock_id': '2465', 'Trading_Volume': 1849688, 'Trading_money': 162632939, 'open': 85.0, 'max': 90.9, 'min': 84.5, 'close': 89.6, 'spread': -1.8, 'Trading_turnover': 1559}
# {'date': '2024-08-09', 'stock_id': '2465', 'Trading_Volume': 1478155, 'Trading_money': 139842386, 'open': 98.5, 'max': 98.5, 'min': 91.7, 'close': 92.3, 'spread': 2.7, 'Trading_turnover': 1375}
# {'date': '2024-08-12', 'stock_id': '2465', 'Trading_Volume': 1232530, 'Trading_money': 113656945, 'open': 92.6, 'max': 94.5, 'min': 90.8, 'close': 91.9, 'spread': -0.4, 'Trading_turnover': 1117}
# {'date': '2024-08-13', 'stock_id': '2465', 'Trading_Volume': 951946, 'Trading_money': 86804088, 'open': 91.9, 'max': 93.0, 'min': 89.3, 'close': 91.6, 'spread': -0.3, 'Trading_turnover': 828}
# {'date': '2024-08-14', 'stock_id': '2465', 'Trading_Volume': 1172604, 'Trading_money': 108637527, 'open': 93.0, 'max': 94.0, 'min': 91.3, 'close': 91.8, 'spread': 0.2, 'Trading_turnover': 1480}
# {'date': '2024-08-15', 'stock_id': '2465', 'Trading_Volume': 651870, 'Trading_money': 60535270, 'open': 92.6, 'max': 93.8, 'min': 91.8, 'close': 93.0, 'spread': 1.2, 'Trading_turnover': 624}
# {'date': '2024-08-16', 'stock_id': '2465', 'Trading_Volume': 1027575, 'Trading_money': 97826725, 'open': 97.6, 'max': 98.0, 'min': 94.1, 'close': 94.2, 'spread': 1.2, 'Trading_turnover': 1264}
# {'date': '2024-08-19', 'stock_id': '2465', 'Trading_Volume': 909690, 'Trading_money': 87403420, 'open': 97.3, 'max': 97.3, 'min': 94.7, 'close': 95.6, 'spread': 1.4, 'Trading_turnover': 923}
# {'date': '2024-08-20', 'stock_id': '2465', 'Trading_Volume': 1236673, 'Trading_money': 120955747, 'open': 96.9, 'max': 99.9, 'min': 96.5, 'close': 96.7, 'spread': 1.1, 'Trading_turnover': 1190}
# {'date': '2024-08-21', 'stock_id': '2465', 'Trading_Volume': 814563, 'Trading_money': 77586371, 'open': 96.7, 'max': 97.2, 'min': 93.8, 'close': 94.2, 'spread': -2.5, 'Trading_turnover': 865}
# {'date': '2024-08-22', 'stock_id': '2465', 'Trading_Volume': 459186, 'Trading_money': 42810048, 'open': 92.8, 'max': 95.0, 'min': 92.2, 'close': 92.6, 'spread': -1.6, 'Trading_turnover': 489}
# {'date': '2024-08-23', 'stock_id': '2465', 'Trading_Volume': 418018, 'Trading_money': 38410667, 'open': 91.0, 'max': 93.4, 'min': 90.6, 'close': 92.8, 'spread': 0.2, 'Trading_turnover': 444}
# {'date': '2024-08-26', 'stock_id': '2465', 'Trading_Volume': 1144759, 'Trading_money': 116095718, 'open': 98.9, 'max': 102.0, 'min': 98.9, 'close': 102.0, 'spread': 9.2, 'Trading_turnover': 815}
# {'date': '2024-08-27', 'stock_id': '2465', 'Trading_Volume': 3481985, 'Trading_money': 378214518, 'open': 105.5, 'max': 111.0, 'min': 104.0, 'close': 109.0, 'spread': 7.0, 'Trading_turnover': 3095}
# {'date': '2024-08-28', 'stock_id': '2465', 'Trading_Volume': 1731816, 'Trading_money': 178909136, 'open': 105.5, 'max': 105.5, 'min': 101.5, 'close': 103.0, 'spread': -6.0, 'Trading_turnover': 3898}
# {'date': '2024-08-29', 'stock_id': '2465', 'Trading_Volume': 1332626, 'Trading_money': 130979559, 'open': 94.5, 'max': 101.5, 'min': 93.6, 'close': 99.1, 'spread': -3.9, 'Trading_turnover': 1373}
# {'date': '2024-08-30', 'stock_id': '2465', 'Trading_Volume': 922217, 'Trading_money': 90887839, 'open': 99.6, 'max': 99.9, 'min': 98.0, 'close': 98.0, 'spread': -1.1, 'Trading_turnover': 933}
# {'date': '2024-09-02', 'stock_id': '2465', 'Trading_Volume': 555855, 'Trading_money': 53371781, 'open': 96.8, 'max': 98.0, 'min': 95.2, 'close': 95.6, 'spread': -2.4, 'Trading_turnover': 683}
# {'date': '2024-09-03', 'stock_id': '2465', 'Trading_Volume': 409701, 'Trading_money': 38953928, 'open': 95.6, 'max': 97.0, 'min': 93.6, 'close': 93.9, 'spread': -1.7, 'Trading_turnover': 551}
# {'date': '2024-09-04', 'stock_id': '2465', 'Trading_Volume': 705430, 'Trading_money': 63072364, 'open': 89.4, 'max': 91.2, 'min': 86.7, 'close': 88.8, 'spread': -5.1, 'Trading_turnover': 836}
# {'date': '2024-09-05', 'stock_id': '2465', 'Trading_Volume': 454960, 'Trading_money': 40491717, 'open': 90.0, 'max': 91.8, 'min': 87.0, 'close': 87.5, 'spread': -1.3, 'Trading_turnover': 539}
# {'date': '2024-09-06', 'stock_id': '2465', 'Trading_Volume': 300464, 'Trading_money': 26419775, 'open': 86.7, 'max': 88.7, 'min': 86.7, 'close': 87.8, 'spread': 0.3, 'Trading_turnover': 392}
# {'date': '2024-09-09', 'stock_id': '2465', 'Trading_Volume': 241246, 'Trading_money': 20764690, 'open': 85.5, 'max': 87.4, 'min': 84.3, 'close': 87.0, 'spread': -0.8, 'Trading_turnover': 339}

# %% [markdown]
# ### SMCI

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo'
r = requests.get(url)
data = r.json()

print(data)

# %%
import matplotlib.pyplot as plt

# 1. 計算收益率
tw_common['Return'] = tw_common['Adj Close'].pct_change().dropna()
us_common['Return'] = us_common['Adj Close'].pct_change().dropna()

# 2. 計算收益率差異（spread）
spread = tw_common['Return'] - us_common['Return']

# 3. 對 spread 進行 Z-score 標準化
spread_mean = spread.mean()
spread_std = spread.std()
spread_z = (spread - spread_mean) / spread_std



# 4. 繪製圖表
fig, ax1 = plt.subplots(figsize=(16, 8))

# 繪製收益率差異的 Z-score
ax1.plot(spread.index, spread_z, label='Spread (Return Difference Z-score)', color='red', linestyle='-', linewidth=2)
ax1.set_xlabel('Date')
ax1.set_ylabel('Standardized Return Spread (Z-score)', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# 繪製成交量的標準化數據


# 設置標題
plt.title('Standardized Spread (Return Difference) Over Last Year')

# 顯示圖例
ax1.legend(loc='upper left')

plt.show()

# %%
# 成交量的百分比變化
tw_common['Volume_pct_change'] = tw_common['Volume'].pct_change().dropna()
us_common['Volume_pct_change'] = us_common['Volume'].pct_change().dropna()

# 成交量的對數變換
tw_common['Volume_log'] = np.log(tw_common['Volume'].replace(0, np.nan)).dropna()  # 替換0以避免對數錯誤
us_common['Volume_log'] = np.log(us_common['Volume'].replace(0, np.nan)).dropna()

# 檢查標準化後的成交量數據
print(tw_common[['Volume_pct_change', 'Volume_log']].head())
print(us_common[['Volume_pct_change', 'Volume_log']].head())

# %%
import vectorbt as vbt
import pandas as pd
import numpy as np

entry_threshold = 2 # 進場的Z-score阈值
exit_threshold = 0.5  # 平仓的Z-score阈值

# 生成交易信号
long_entries = spread_z < -entry_threshold  # 当 Z-score 低于 -entry_threshold，做多台股，做空美股
long_exits = spread_z > -exit_threshold     # 当 Z-score 接近 0 时平仓

short_entries = spread_z > entry_threshold  # 当 Z-score 高于 entry_threshold，做空台股，做多美股
short_exits = spread_z < exit_threshold     # 当 Z-score 接近 0 时平仓


# 根據 Z-score 動態調整倉位
long_size = np.where(spread_z < -entry_threshold, abs(spread_z / spread_z.min()), 0)
short_size = np.where(spread_z > entry_threshold, abs(spread_z / spread_z.max()), 0)



# 创建投资组合
pf = vbt.Portfolio.from_signals(
    tw_common['Adj Close'],  # 使用台股收盘价作为基准
    entries=long_entries,
    exits=long_exits,
    short_entries=short_entries,  
    short_exits=short_exits,
    freq='d',  # 设置为每日
    fees=0.0014,  # 假设交易费率
    slippage=0.001,  # 假設 0.1% 的滑點
    
)

# 打印回测结果
stats = pf.stats()
print(stats)

# %% [markdown]
# ### BT

# %%
# split_time = pd.to_datetime('2024-05-01')
# portfolio_value = pf.returns().cumsum()+1
# portfolio_value.reset_index(drop=True, inplace=True)
# Close = tw_common['Adj Close']
# Open_time = Close.index
# Open_time = pd.Series(pd.to_datetime(Open_time))
# Close.reset_index(drop=True, inplace=True)
# ppl.plot_equity_curve(portfolio_value, Close, Open_time, split_time)
